# %%
import pyfdmt
import numpy as np
import matplotlib.pyplot as pyplot

# %%
pulse = np.load("./pulse_linear.npy")

# %%
pyplot.imshow(pulse)

# %%
(4096 * 2 * 1e-6)
# Out:
# 0.008192

# %%
f_ch1 = 1420
f_chn = f_ch1 + (4096 * 2 * 1e-6)
fdmt_out = pyfdmt.transform(pulse.T,1421,1420,1e-3,0,2000)

# %%
4096 * 2 * 1e-6
# Out:
# 0.008192

# %%
pulse.shape
# Out:
# (512, 4096)

# %%
pyfdmt.transform()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-5864ba5ac6d5> in <module>
# ----> 1 pyfdmt.transform()
#
# TypeError: transform() missing 6 required positional arguments: 'data', 'fch1', 'fchn', 'tsamp', 'dm_min', and 'dm_max'

# %%
fdmt_out.plot()

# %%
fdmt_out.ymax
# Out:
# 2075
