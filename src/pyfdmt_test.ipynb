# %%
import pyfdmt
import numpy as np
import matplotlib.pyplot as pyplot

# %%
pulse = np.load("../dispersed_pulse.npz")

# %%
pyplot.imshow(pulse)

# %%
pulse.shape
# Out:
# (3000, 4096)

# %%
fdmt_out = pyfdmt.transform(pulse.T,1500,1200,1e-3,0,2000)

# %%
fdmt_out.plot();

# %%
fdmt_out.data.shape
# Out:
# (2076, 3000)
